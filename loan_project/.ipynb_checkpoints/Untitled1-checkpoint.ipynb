# %%
import re

# %%
txt = """00:23:11,791 --> 00:23:13,250
Das… Das ist doch Quatsch.

370
00:23:13,333 --> 00:23:16,291
Sie arbeiten beim
VEB Unterhaltungselektronik Sternradio.

371
00:23:16,375 --> 00:23:18,416
Richtig. In der Produktion.

372
00:23:19,166 --> 00:23:20,791
Wie erklären Sie sich das hier?

373
00:23:20,875 --> 00:23:22,833
[Im Hintergrund wird mitgetippt]

374
00:23:24,958 --> 00:23:27,041
Ich bin zufällig
mit diesem Mann zusammengestoßen.

375
00:23:27,125 --> 00:23:30,000
Dieser Mann
ist ein feindlicher Agent aus der BRD.

376
00:23:30,083 --> 00:23:32,791
Er wurde kurz darauf
beim Grenzübertritt festgesetzt.

377
00:23:32,875 --> 00:23:38,041
Sie rufen nun bei der HVA-Abteilung 18 an.
Dann wird man das hier alles aufklären.

378
00:23:38,125 --> 00:23:40,541
Sie sind von Ihrem Großvater
aufgezogen worden.

379
00:23:40,625 --> 00:23:45,916
Richtig. Und mein Großvater arbeitet
bei der HVA-Abteilung 1. Fragen Sie ihn.

380
00:23:46,000 --> 00:23:48,958
Im gesamten Register
des Ministeriums für Staatssicherheit

381
00:23:49,041 --> 00:23:52,166
ist keine Person
mit dem Namen Kleo Straub geführt.

382
00:23:52,250 --> 00:23:54,416
Lügen Sie mit dem Versuch
der Vorteilsnahme?

383
00:23:54,500 --> 00:23:55,583
[wütend] Nein!

384
00:23:55,666 --> 00:23:59,208
Ich bin inoffizielle Mitarbeiterin
der Staatssicherheit!

385
00:23:59,291 --> 00:24:01,666
HVA-Abteilung 18.

386
00:24:01,750 --> 00:24:04,625
Ich war erfolgreich
an 12 Einsätzen beteiligt.

387
00:24:04,708 --> 00:24:06,083
Darüber gibt es Akten.

388
00:24:06,166 --> 00:24:08,375
Rufen Sie meinen Führungsoffizier an.

389
00:24:08,458 --> 00:24:10,375
Keine Sorge. Das werden wir.

390
00:24:10,458 --> 00:24:12,708
[ernste Klänge, Schreibmaschine klingelt]

391
00:24:18,833 --> 00:24:20,583
[laute, unheilvolle Klänge]

392
00:24:20,666 --> 00:24:22,791
[Frau] <i>Das Urteil lautet wie folgt:</i>

393
00:24:22,875 --> 00:24:28,833
Nach § 96 und 97 des Strafgesetzbuchs
der Deutschen Demokratischen Republik

394
00:24:28,916 --> 00:24:35,666
wird die Angeklagte Kleo Jennifer Straub,
geboren am 2.9.1964,

395
00:24:35,750 --> 00:24:40,958
aufgrund des besonders schweren Falles
von Hochverrat und Spionage

396
00:24:41,041 --> 00:24:44,541
zu einer lebenslangen
Freiheitsstrafe verurteilt.

397
00:24:44,625 --> 00:24:47,000
[verzerrte Klänge, wummerndes Tippen]

398
00:24:47,875 --> 00:24:51,000
Ich verlange,
dass meine Zeugen gehört werden.

399
00:24:51,083 --> 00:24:53,916
[Richterin] Die sind alle verhört worden,
Frau Straub.

400
00:24:54,000 --> 00:24:56,791
Und die haben Ihnen ja gesagt,
für wen ich arbeite.

401
00:24:56,875 --> 00:24:59,958
Die Zeugen haben sämtlichst
00:27:48,000 --> 00:27:50,000
-Meine Güte, ein geiler Film.
-Wirklich…

440
00:27:50,083 --> 00:27:51,000
[Frau] Was darf's sein?

441
00:27:51,083 --> 00:27:53,416
-Scheiße, was nehmen wir?
-Zweimal Curry.

442
00:27:53,500 --> 00:27:54,666
-Jo.
-Gut.

443
00:27:55,250 --> 00:27:56,958
Hier, Kollege Petzold.

444
00:27:57,041 --> 00:27:58,125
-[Sven] Ja?
-Komm mal.

445
00:28:01,333 --> 00:28:02,625
Ähm. [räuspert sich]

446
00:28:02,708 --> 00:28:04,375
-Der Eden-Fall…
-Ja?

447
00:28:04,458 --> 00:28:06,125
-Du erinnerst dich?
-Ja, natürlich.

448
00:28:07,000 --> 00:28:09,708
Da sind die Ermittlungen eingestellt.

449
00:28:11,291 --> 00:28:13,375
Was? Wieso?

450
00:28:13,458 --> 00:28:16,583
Ja, der Typ starb an einer Überdosis.
Also, kein Mord.

451
00:28:16,666 --> 00:28:19,291
Aber die Frau hatte 'n Messer dabei,
hier am Bein.

452
00:28:19,375 --> 00:28:22,000
Wer bringt 'n Messer
in eine Scheiß-Disco mit, oder?

453
00:28:22,083 --> 00:28:24,250
Es wäre ein Indiz,
wäre er erstochen worden,

454
00:28:24,333 --> 00:28:26,125
aber wurde er das? Ich denke, nein.
"""

# %%
for i in txt:
    if i in

# %%
sub = re.findall(r'\b[A-Za-z\s\.,\'’?!-]+\b', txt)

# %%
txt
# Out:
# '00:23:11,791 --> 00:23:13,250\nDas… Das ist doch Quatsch.\n\n370\n00:23:13,333 --> 00:23:16,291\nSie arbeiten beim\nVEB Unterhaltungselektronik Sternradio.\n\n371\n00:23:16,375 --> 00:23:18,416\nRichtig. In der Produktion.\n\n372\n00:23:19,166 --> 00:23:20,791\nWie erklären Sie sich das hier?\n\n373\n00:23:20,875 --> 00:23:22,833\n[Im Hintergrund wird mitgetippt]\n\n'

# %%
subtitles = re.findall(r'\d+:\d+:\d+,\d+ --> \d+:\d+:\d+,\d+\n(.+?)\n', txt, re.DOTALL)

# Join the extracted subtitles into a single string
subtitles_text = ' '.join(subtitles)

# %%
subtitles_text
# Out:
# 'Das… Das ist doch Quatsch. Sie arbeiten beim Richtig. In der Produktion. Wie erklären Sie sich das hier? [Im Hintergrund wird mitgetippt]'

# %%
import re
import string


# Use regular expressions to extract only the subtitles
subtitles = re.findall(r'\d+:\d+:\d+,\d+ --> \d+:\d+:\d+,\d+\n(.+?)\n', txt, re.DOTALL)

# Remove punctuation from the extracted subtitles
translator = str.maketrans("", "", string.punctuation)
subtitles_cleaned = [subtitle.translate(translator) for subtitle in subtitles]


# Join the cleaned subtitles into a single string
subtitles_text = '\n'.join(subtitles_cleaned)



print(subtitles_text)
# Out:
# Das… Das ist doch Quatsch
# Sie arbeiten beim
# Richtig In der Produktion
# Wie erklären Sie sich das hier
# Im Hintergrund wird mitgetippt
# Ich bin zufällig
# Dieser Mann
# Er wurde kurz darauf
# Sie rufen nun bei der HVAAbteilung 18 an
# Sie sind von Ihrem Großvater
# Richtig Und mein Großvater arbeitet
# Im gesamten Register
# ist keine Person
# Lügen Sie mit dem Versuch
# wütend Nein
# Ich bin inoffizielle Mitarbeiterin
# HVAAbteilung 18
# Ich war erfolgreich
# Darüber gibt es Akten
# Rufen Sie meinen Führungsoffizier an
# Keine Sorge Das werden wir
# ernste Klänge Schreibmaschine klingelt
# laute unheilvolle Klänge
# Frau iDas Urteil lautet wie folgti
# Nach § 96 und 97 des Strafgesetzbuchs
# wird die Angeklagte Kleo Jennifer Straub
# aufgrund des besonders schweren Falles
# zu einer lebenslangen
# verzerrte Klänge wummerndes Tippen
# Ich verlange
# Richterin Die sind alle verhört worden
# Und die haben Ihnen ja gesagt
# Die Zeugen haben sämtlichst
# ...

# %%
if '…' in subtitles_text:
    subtitles_text.replace('…', ' ')

# %%
subtitles_text
# Out:
# 'Das… Das ist doch Quatsch\nSie arbeiten beim\nRichtig In der Produktion\nWie erklären Sie sich das hier\nIm Hintergrund wird mitgetippt\nIch bin zufällig\nDieser Mann\nEr wurde kurz darauf\nSie rufen nun bei der HVAAbteilung 18 an\nSie sind von Ihrem Großvater\nRichtig Und mein Großvater arbeitet\nIm gesamten Register\nist keine Person\nLügen Sie mit dem Versuch\nwütend Nein\nIch bin inoffizielle Mitarbeiterin\nHVAAbteilung 18\nIch war erfolgreich\nDarüber gibt es Akten\nRufen Sie meinen Führungsoffizier an\nKeine Sorge Das werden wir\nernste Klänge Schreibmaschine klingelt\nlaute unheilvolle Klänge\nFrau iDas Urteil lautet wie folgti\nNach § 96 und 97 des Strafgesetzbuchs\nwird die Angeklagte Kleo Jennifer Straub\naufgrund des besonders schweren Falles\nzu einer lebenslangen\nverzerrte Klänge wummerndes Tippen\nIch verlange\nRichterin Die sind alle verhört worden\nUnd die haben Ihnen ja gesagt\nDie Zeugen haben sämtlichst\nDie Kollegen vom Sternradio\nund Ihr Großvater\nschreit Das
# ...

# %%
subtitles_text
# Out:
# 'Das… Das ist doch Quatsch\nSie arbeiten beim\nRichtig In der Produktion\nWie erklären Sie sich das hier\nIm Hintergrund wird mitgetippt\nIch bin zufällig\nDieser Mann\nEr wurde kurz darauf\nSie rufen nun bei der HVAAbteilung 18 an\nSie sind von Ihrem Großvater\nRichtig Und mein Großvater arbeitet\nIm gesamten Register\nist keine Person\nLügen Sie mit dem Versuch\nwütend Nein\nIch bin inoffizielle Mitarbeiterin\nHVAAbteilung 18\nIch war erfolgreich\nDarüber gibt es Akten\nRufen Sie meinen Führungsoffizier an\nKeine Sorge Das werden wir\nernste Klänge Schreibmaschine klingelt\nlaute unheilvolle Klänge\nFrau iDas Urteil lautet wie folgti\nNach § 96 und 97 des Strafgesetzbuchs\nwird die Angeklagte Kleo Jennifer Straub\naufgrund des besonders schweren Falles\nzu einer lebenslangen\nverzerrte Klänge wummerndes Tippen\nIch verlange\nRichterin Die sind alle verhört worden\nUnd die haben Ihnen ja gesagt\nDie Zeugen haben sämtlichst\nDie Kollegen vom Sternradio\nund Ihr Großvater\nschreit Das
# ...
